# %%
from ultralytics import YOLO
from matplotlib import pyplot as plt
from PIL import Image

# %%
#detection model
det_model = YOLO('yolov8x.pt')
#instance model
inst_model = YOLO('yolov8x-seg.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8x.pt to 'yolov8x.pt'...
# ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8x.pt...
# ######################################################################## 100.0%
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8x-seg.pt to 'yolov8x-seg.pt'...
# ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8x-seg.pt...
# ######################################################################## 100.0%###################################                          68.0%

# %%
img = '/Users/nikhil/Projects/SegmentationProjects/IMG_1609 copy.JPG'
detection_results = det_model.predict(img)
instance_results = inst_model.predict(img)
# Out:
# image 1/1 /Users/nikhil/Projects/SegmentationProjects/IMG_1609 copy.JPG: 640x384 1 bowl, 63.3ms
# Speed: 2.5ms preprocess, 63.3ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /Users/nikhil/Projects/SegmentationProjects/IMG_1609 copy.JPG: 640x384 1 bowl, 65.6ms
# Speed: 1.8ms preprocess, 65.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)

# %%
detection_result_array = detection_results[0].plot()
instance_result_array = instance_results[0].plot()
fig = plt.figure(figsize=(18, 9))
ax1 = fig.add_subplot(1,2,1)
ax1.set_title("Object Detection")
ax1.imshow(detection_result_array)
ax2 = fig.add_subplot(1,2,2)
ax2.set_title("Instance Segmentation")
ax2.imshow(instance_result_array)
